# %% [markdown]
# <h1 style="font-size: 32px; text-align: center;">Introduction to Computer Programming for the Physical Sciences</h1>
# <h2 style="font-size: 24px; text-align: center;">Joseph F. Hennawi</h2>
# <h3 style="font-size: 24px; text-align: center;">Winter 2024</h2>

# %% [markdown]
# ## Working on Section Problems
#
# <ul style="list-style: none;">
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Get into groups of 2 or 3, with at least one laptop per group.</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Discuss with each other and attempt each problem yourselves first without AI support for 10-15 mins.</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;">
# </span>Input the problem prompt into the AI chatbox, use its answer to verify your own, or to learn how it should be solved.</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;">
# </span>For section problems, you can omit most of the commenting and focus on learning coding. For more difficult problems, minimal comments are still recommended as a way of organizing your own thoughts.</li>
#   <li style="margin-bottom: 10px; font-size: 20px;"><span style="display: inline-block; width: 10px; height: 10px; border: 2px solid black; margin-right: 10px;"></span>Please abide by the <b><a href="https://github.com/enigma-igm/Phys29/blob/main/using_AI_tools.md">Policy and Guidelines on Using AI Tools</a></b></li>

# %% [markdown]
# # Section 9

# %% [markdown]
# ## Problem 1

# %%
import numpy as np
import scipy
import scipy.stats as stats
from scipy import optimize
import matplotlib.pyplot as plt

# %% [markdown]
# In lecture, we have introduced how to sample from an arbitrary distribution using a change of variables.
#
# Consider the probability distribution:
# \begin{equation}
#   P(y) =
#     \begin{cases}
#       3y^2 & 0 \leq x \leq 1 \\
#       0 & otherwise
#     \end{cases}
# \end{equation}
#
# $3y^2$ is not a probability distribution that we can sample using ```numpy.random```, but as we have seen in lecture, we can sample from a uniform distribution: $P(x)=U(x)$, using ```numpy.random.uniform```, and find a function $y(x)$ which allows us to transform $P(x)$ to the desired distribution via $P(y) = P(x)|\frac{dx}{dy}|$.
#
# Find the function y(x) that transforms uniform probability distribution to P(y) (No coding fo this problem).

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Radioactive isotopes turn into other more stable isotopes by emitting particles such as electrons. This process is called radioactive decay. This decay rate is exponential, and is often characterized by its "half-life", which is the time it takes for the amount of a radioactive isotope to decrease by half.
#
# The file Indium_Counts.txt contains two columns: (1) the measurement time in minutes, (2) the radioactivity counts, which directly corresponds to the amount of radioactive Indium isotope remaining. Assume the time measurement is perfect (no errors), and the radioactivity counts has a measurement error of 100 counts for all data points.
#
# a. Load the data and make a scatter plot of counts as a function of time. Please include error bars on counts.
#
# b. For simplicity, we'll assume background radation is already removed from the data. Then, the radioactive counts, R(t), is given by:
# $$
# R(t) = R_0 e^{-t/\tau}
# $$
# where $R_0$ is the initial radioactive count at $t=0$, and $\tau$ is the half-life of the isotope. Plot this equation on top of your scatter plot and try to choose $R_0$ and $\tau$ so that your line approximately goes through the points. What are your estimates for $R_0$ and $\tau$?
#
# c. Write a function that calculates the $\chi^2$ residuals (chi square) between the data and a exponential model:
# $$
# \chi^2 = \sum_i (\frac{y_i - m_i}{\sigma_{y_i}})^2
# $$
# Where $y_i$ are the data points, $m_i$ are your model values. Your function would take as arguments: params, R_data, data_sig, t_obs. Where params is a list $[R_0, \tau]$, R_data is the data array containing the measured counts in Indium_Counts.txt, data_sig is the measurement error (100 in this case), and t_obs is an array of the times the data were measured. Use this to calculate the chi square of your manually estimated model from part b.
#
# d. Use scipy.optimize.minimize to minimize the chi square function you wrote in part c, with your manual estimate in part b as the initial guesses for $R_0$ and $\tau$.
